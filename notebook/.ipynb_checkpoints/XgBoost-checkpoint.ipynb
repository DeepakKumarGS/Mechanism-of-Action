# %%
#Import rapids library,
import sys
# !cp ../input/rapids/rapids.0.14.0 /opt/conda/envs/rapids.tar.gz
# !cd /opt/conda/envs/ && tar -xzvf rapids.tar.gz > /dev/null
sys.path = ["/opt/conda/envs/rapids/lib/python3.7/site-packages"] + sys.path
sys.path = ["/opt/conda/envs/rapids/lib/python3.7"] + sys.path
sys.path = ["/opt/conda/envs/rapids/lib"] + sys.path 
# !cp /opt/conda/envs/rapids/lib/libxgboost.so /opt/conda/lib/

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load
#import cudf
#import cupy as cp
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import lightgbm as lgb
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/lish-moa/test_features.csv
# /kaggle/input/lish-moa/sample_submission.csv
# /kaggle/input/lish-moa/train_features.csv
# /kaggle/input/lish-moa/train_targets_scored.csv
# /kaggle/input/lish-moa/train_targets_nonscored.csv
# /kaggle/input/rapids/rapids.0.14.0
# /kaggle/input/rapids/rapids.0.15.0

# %%
#cudf.__version__

# %%
from sklearn.metrics import roc_auc_score
#from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedKFold
from collections import defaultdict
#from cuml.linear_model import LogisticRegression

# %%
train_features=pd.read_csv('../input/lish-moa/train_features.csv')
test_features=pd.read_csv('../input/lish-moa/test_features.csv')
train_targets_scored=pd.read_csv('../input/lish-moa/train_targets_scored.csv')
sample_submission=pd.read_csv('../input/lish-moa/sample_submission.csv')

# %%
train_features.head()
# Out:
#          sig_id cp_type  cp_time cp_dose     g-0     g-1     g-2     g-3  \
# 0  id_000644bb2  trt_cp       24      D1  1.0620  0.5577 -0.2479 -0.6208
# 1  id_000779bfc  trt_cp       72      D1  0.0743  0.4087  0.2991  0.0604
# 2  id_000a6266a  trt_cp       48      D1  0.6280  0.5817  1.5540 -0.0764
# 3  id_0015fd391  trt_cp       48      D1 -0.5138 -0.2491 -0.2656  0.5288
# 4  id_001626bd3  trt_cp       72      D2 -0.3254 -0.4009  0.9700  0.6919
#
#       g-4     g-5  ...    c-90    c-91    c-92    c-93    c-94    c-95  \
# 0 -0.1944 -1.0120  ...  0.2862  0.2584  0.8076  0.5523 -0.1912  0.6584
# 1  1.0190  0.5207  ... -0.4265  0.7543  0.4708  0.0230  0.2957  0.4899
# 2 -0.0323  1.2390  ... -0.7250 -0.6297  0.6103  0.0223 -1.3240 -0.3174
# 3  4.0620 -0.8095  ... -2.0990 -0.6441 -5.6300 -1.3780 -0.8632 -1.2880
# 4  1.4180 -0.8244  ...  0.0042  0.0048  0.6670  1.0690  0.5523 -0.3031
#
#      c-96    c-97    c-98    c-99
# 0 -0.3981  0.2139  0.3801  0.4176
# 1  0.1522  0.1241  0.6077  0.7371
# 2 -0.6417 -0.2187 -1.4080  0.6931
# 3 -1.6210 -0.8784 -0.3876 -0.8154
# 4  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 876 columns]

# %%
targets=train_targets_scored.columns[1:]
len(targets)
# Out:
# 206

# %%
##train features,
train_features=pd.concat([train_features,pd.get_dummies(train_features['cp_time'],prefix='cp_time')],axis=1)
train_features=pd.concat([train_features,pd.get_dummies(train_features['cp_type'],prefix='cp_type')],axis=1)
train_features=pd.concat([train_features,pd.get_dummies(train_features['cp_dose'],prefix='cp_dose')],axis=1)
train_features=train_features.drop(['cp_time','cp_type','cp_dose'],axis=1)

#test features,
test_features=pd.concat([test_features,pd.get_dummies(test_features['cp_time'],prefix='cp_time')],axis=1)
test_features=pd.concat([test_features,pd.get_dummies(test_features['cp_type'],prefix='cp_type')],axis=1)
test_features=pd.concat([test_features,pd.get_dummies(test_features['cp_dose'],prefix='cp_dose')],axis=1)
test_features=test_features.drop(['cp_time','cp_type','cp_dose'],axis=1)

# %%
kfolds=StratifiedKFold(n_splits=5,random_state=42,shuffle=True)

# %%
tar=['5-alpha_reductase_inhibitor','atp-sensitive_potassium_channel_antagonist','11-beta-hsd1_inhibitor']

# %%
feats=[c for c in train_features.columns if c not in ['sig_id']]

# %%
def log_loss_metric(y_true,y_preds):
    """
    Custom Log loss
    """
    y_preds_clipped=np.clip(y_preds,1e-15,1-1e-15)
    loss=np.mean(y_true*np.log(y_preds_clipped) + (1-y_true)*np.log(1-y_preds_clipped))
    return loss

# %%
scores=[]
oof_preds=np.zeros(train_features.shape[0])
sub_preds=np.zeros(test_features.shape[0])
feature_importance_df=pd.DataFrame()
non_pred_class=[]
score_dict=dict()
lgb_round_dict=defaultdict(int)
for class_name in targets:
    class_preds=np.zeros(len(train_targets_scored))
    train_targets=train_targets_scored[class_name]
    if train_targets.sum()>5:
        for fold_,(trn_,val_) in enumerate(kfolds.split(train_features,train_targets)):
            print(f'Started training fold {fold_} and class name {class_name}')
            trn_x,trn_y=train_features[feats].iloc[trn_],train_targets.iloc[trn_]
            val_x,val_y=train_features[feats].iloc[val_],train_targets.iloc[val_]
            #print(type(trn_x),type(trn_y),type(val_x),type(val_y))
            clf=lgb.LGBMClassifier(
            n_estimators=4000,
            learning_rate=0.03,
            num_leaves=30,
            colsample_bytree=.8,
            subsample=.9,
            max_depth=7,
            reg_alpha=.1,
            reg_lambda=.1,
            min_split_gain=.01,
            min_child_weight=2,
            silent=-1,
            verbose=-1,
            importance_type='split',
            device='gpu'
        )
        
            clf.fit(trn_x,trn_y,eval_set=[(trn_x,trn_y),(val_x,val_y)],early_stopping_rounds=50,
                         verbose=50)
            #print(model.best_iteration)
            class_preds[val_]=clf.predict_proba(val_x,num_iteration=clf.best_iteration_)[:,1]
            lgb_round_dict[class_name]+=clf.best_iteration_
            score=roc_auc_score(train_targets[val_],class_preds[val_])
            sub_preds+=clf.predict_proba(test_features[feats],num_iteration=clf.best_iteration_)[:,1]/5
            print(f'Fold {fold_} Class name {class_name} AUC {score} in {clf.best_iteration_} rounds')
            fold_importance_df=pd.DataFrame()
            fold_importance_df['features']=feats
            fold_importance_df['importance']=clf.feature_importances_
            fold_importance_df['class_names']=class_name
            fold_importance_df['folds']=fold_
            feature_importance_df=pd.concat([feature_importance_df,fold_importance_df],axis=0) 
           # print(feature_importance_df.head())
            
        sample_submission[class_name]=sub_preds
        print(f'------Class {class_name} Full AUC Score  {roc_auc_score(train_targets,class_preds)}------')
        train_targets_scored[class_name+'_oof']=class_preds
        scores.append(roc_auc_score(train_targets,class_preds))
        score_dict[class_name]=roc_auc_score(train_targets,class_preds)
        
    else:
        non_pred_class.append(class_name)

    
print(f'Total CV Score {np.mean(scores)}')
# Out:
# Started training fold 0 and class name 5-alpha_reductase_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00328237	valid_1's binary_logloss: 0.00532572
# Early stopping, best iteration is:
# [3]	training's binary_logloss: 0.00588211	valid_1's binary_logloss: 0.00526151
# Fold 0 Class name 5-alpha_reductase_inhibitor AUC 0.5705532212885154 in 3 rounds
# Started training fold 1 and class name 5-alpha_reductase_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00335626	valid_1's binary_logloss: 0.00511958
# [100]	training's binary_logloss: 0.00131699	valid_1's binary_logloss: 0.00501936
# Early stopping, best iteration is:
# [96]	training's binary_logloss: 0.00141873	valid_1's binary_logloss: 0.00501321
# Fold 1 Class name 5-alpha_reductase_inhibitor AUC 0.7628851540616246 in 96 rounds
# Started training fold 2 and class name 5-alpha_reductase_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00329129	valid_1's binary_logloss: 0.0060159
# [100]	training's binary_logloss: 0.00154686	valid_1's binary_logloss: 0.00583829
# [150]	training's binary_logloss: 0.000713693	valid_1's binary_logloss: 0.00577191
# Early stopping, best iteration is:
# [113]	training's binary_logloss: 0.00123192	valid_1's binary_logloss: 0.0057426
# Fold 2 Class name 5-alpha_reductase_inhibitor AUC 0.9222525740701828 in 113 rounds
# Started training fold 3 and class name 5-alpha_reductase_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00315622	valid_1's binary_logloss: 0.00639275
# [100]	training's binary_logloss: 0.00132737	valid_1's binary_logloss: 0.00633879
# Early stopping, best iteration is:
# [78]	training's binary_logloss: 0.00201158	valid_1's binary_logloss: 0.00629769
# Fold 3 Class name 5-alpha_reductase_inhibitor AUC 0.8535931918470266 in 78 rounds
# Started training fold 4 and class name 5-alpha_reductase_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00347939	valid_1's binary_logloss: 0.00448645
# [100]	training's binary_logloss: 0.00138937	valid_1's binary_logloss: 0.0041435
# [150]	training's binary_logloss: 0.000654617	valid_1's binary_logloss: 0.00418391
# Early stopping, best iteration is:
# [100]	training's binary_logloss: 0.00138937	valid_1's binary_logloss: 0.0041435
# Fold 4 Class name 5-alpha_reductase_inhibitor AUC 0.9659592351334314 in 100 rounds
# ------Class 5-alpha_reductase_inhibitor Full AUC Score  0.830160252528124------
# Started training fold 0 and class name 11-beta-hsd1_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00383441	valid_1's binary_logloss: 0.00545409
# Early stopping, best iteration is:
# [9]	training's binary_logloss: 0.00588595	valid_1's binary_logloss: 0.00526015
# Fold 0 Class name 11-beta-hsd1_inhibitor AUC 0.6883053221288515 in 9 rounds
# Started training fold 1 and class name 11-beta-hsd1_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00346378	valid_1's binary_logloss: 0.00702705
# Early stopping, best iteration is:
# [11]	training's binary_logloss: 0.00532865	valid_1's binary_logloss: 0.00676925
# Fold 1 Class name 11-beta-hsd1_inhibitor AUC 0.6369773061567556 in 11 rounds
# Started training fold 2 and class name 11-beta-hsd1_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00373015	valid_1's binary_logloss: 0.00677942
# Early stopping, best iteration is:
# [26]	training's binary_logloss: 0.00476056	valid_1's binary_logloss: 0.00670473
# Fold 2 Class name 11-beta-hsd1_inhibitor AUC 0.6926350073544862 in 26 rounds
# Started training fold 3 and class name 11-beta-hsd1_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00371748	valid_1's binary_logloss: 0.00659134
# Early stopping, best iteration is:
# [29]	training's binary_logloss: 0.00459652	valid_1's binary_logloss: 0.00643234
# Fold 3 Class name 11-beta-hsd1_inhibitor AUC 0.8264341248161379 in 29 rounds
# Started training fold 4 and class name 11-beta-hsd1_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00343781	valid_1's binary_logloss: 0.00553819
# Early stopping, best iteration is:
# [7]	training's binary_logloss: 0.00598159	valid_1's binary_logloss: 0.00522687
# Fold 4 Class name 11-beta-hsd1_inhibitor AUC 0.5559291167612243 in 7 rounds
# ------Class 11-beta-hsd1_inhibitor Full AUC Score  0.6898790179488616------
# Started training fold 0 and class name acat_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00502028	valid_1's binary_logloss: 0.00860864
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.00783792	valid_1's binary_logloss: 0.00828144
# Fold 0 Class name acat_inhibitor AUC 0.3003362757461118 in 1 rounds
# Started training fold 1 and class name acat_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00501535	valid_1's binary_logloss: 0.00850769
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.00784432	valid_1's binary_logloss: 0.00825862
# Fold 1 Class name acat_inhibitor AUC 0.4532156368221942 in 1 rounds
# Started training fold 2 and class name acat_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00497253	valid_1's binary_logloss: 0.00837703
# Early stopping, best iteration is:
# [8]	training's binary_logloss: 0.00732417	valid_1's binary_logloss: 0.00826354
# Fold 2 Class name acat_inhibitor AUC 0.5873476250525431 in 8 rounds
# Started training fold 3 and class name acat_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00526376	valid_1's binary_logloss: 0.00888866
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.0078394	valid_1's binary_logloss: 0.00827241
# Fold 3 Class name acat_inhibitor AUC 0.3743799915931063 in 1 rounds
# Started training fold 4 and class name acat_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00527319	valid_1's binary_logloss: 0.00706756
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.00820127	valid_1's binary_logloss: 0.00680086
# Fold 4 Class name acat_inhibitor AUC 0.5847782681799075 in 1 rounds
# ------Class acat_inhibitor Full AUC Score  0.44420975199663726------
# Started training fold 0 and class name acetylcholine_receptor_agonist
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.0235537	valid_1's binary_logloss: 0.0449077
# [100]	training's binary_logloss: 0.0123884	valid_1's binary_logloss: 0.0451918
# Early stopping, best iteration is:
# [72]	training's binary_logloss: 0.0170859	valid_1's binary_logloss: 0.0446593
# Fold 0 Class name acetylcholine_receptor_agonist AUC 0.7061876914508494 in 72 rounds
# Started training fold 1 and class name acetylcholine_receptor_agonist
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.024801	valid_1's binary_logloss: 0.0459441
# [100]	training's binary_logloss: 0.0139572	valid_1's binary_logloss: 0.0467019
# Early stopping, best iteration is:
# [53]	training's binary_logloss: 0.0239257	valid_1's binary_logloss: 0.0458411
# Fold 1 Class name acetylcholine_receptor_agonist AUC 0.6267112225006961 in 53 rounds
# Started training fold 2 and class name acetylcholine_receptor_agonist
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.0225528	valid_1's binary_logloss: 0.0453784
# [100]	training's binary_logloss: 0.0123078	valid_1's binary_logloss: 0.0454137
# Early stopping, best iteration is:
# [63]	training's binary_logloss: 0.0190962	valid_1's binary_logloss: 0.0450747
# Fold 2 Class name acetylcholine_receptor_agonist AUC 0.680735171261487 in 63 rounds
# Started training fold 3 and class name acetylcholine_receptor_agonist
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.0222921	valid_1's binary_logloss: 0.045801
# [100]	training's binary_logloss: 0.0121068	valid_1's binary_logloss: 0.045544
# Early stopping, best iteration is:
# [96]	training's binary_logloss: 0.0125834	valid_1's binary_logloss: 0.045458
# Fold 3 Class name acetylcholine_receptor_agonist AUC 0.6825174046226679 in 96 rounds
# Started training fold 4 and class name acetylcholine_receptor_agonist
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.0224048	valid_1's binary_logloss: 0.045581
# [100]	training's binary_logloss: 0.0122962	valid_1's binary_logloss: 0.0458184
# Early stopping, best iteration is:
# [63]	training's binary_logloss: 0.0187439	valid_1's binary_logloss: 0.0453459
# Fold 4 Class name acetylcholine_receptor_agonist AUC 0.6587860421587415 in 63 rounds
# ------Class acetylcholine_receptor_agonist Full AUC Score  0.6701940043131873------
# Started training fold 0 and class name acetylcholine_receptor_antagonist
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.03945	valid_1's binary_logloss: 0.0668088
# Early stopping, best iteration is:
# [41]	training's binary_logloss: 0.0435304	valid_1's binary_logloss: 0.0665209
# Fold 0 Class name acetylcholine_receptor_antagonist AUC 0.6234920972428946 in 41 rounds
# Started training fold 1 and class name acetylcholine_receptor_antagonist
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.0410848	valid_1's binary_logloss: 0.0659973
# [100]	training's binary_logloss: 0.0263252	valid_1's binary_logloss: 0.0657269
# [150]	training's binary_logloss: 0.0183631	valid_1's binary_logloss: 0.0663143
# Early stopping, best iteration is:
# [104]	training's binary_logloss: 0.0256338	valid_1's binary_logloss: 0.0656698
# Fold 1 Class name acetylcholine_receptor_antagonist AUC 0.6672584874902545 in 104 rounds
# Started training fold 2 and class name acetylcholine_receptor_antagonist
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.0406933	valid_1's binary_logloss: 0.0663505
# [100]	training's binary_logloss: 0.0264759	valid_1's binary_logloss: 0.0663672
# Early stopping, best iteration is:
# [78]	training's binary_logloss: 0.0320203	valid_1's binary_logloss: 0.0660048
# Fold 2 Class name acetylcholine_receptor_antagonist AUC 0.6443865617690836 in 78 rounds
# Started training fold 3 and class name acetylcholine_receptor_antagonist
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.0422013	valid_1's binary_logloss: 0.0665806
# [100]	training's binary_logloss: 0.0265525	valid_1's binary_logloss: 0.0665814
# Early stopping, best iteration is:
# [80]	training's binary_logloss: 0.0314776	valid_1's binary_logloss: 0.0661128
# Fold 3 Class name acetylcholine_receptor_antagonist AUC 0.6741254157630865 in 80 rounds
# Started training fold 4 and class name acetylcholine_receptor_antagonist
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.0403948	valid_1's binary_logloss: 0.0657397
# [100]	training's binary_logloss: 0.0268217	valid_1's binary_logloss: 0.0653456
# Early stopping, best iteration is:
# [89]	training's binary_logloss: 0.0291928	valid_1's binary_logloss: 0.0652449
# Fold 4 Class name acetylcholine_receptor_antagonist AUC 0.6733801219339288 in 89 rounds
# ------Class acetylcholine_receptor_antagonist Full AUC Score  0.6552813860092664------
# Started training fold 0 and class name acetylcholinesterase_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00881444	valid_1's binary_logloss: 0.0196456
# Early stopping, best iteration is:
# [47]	training's binary_logloss: 0.00939305	valid_1's binary_logloss: 0.0196448
# Fold 0 Class name acetylcholinesterase_inhibitor AUC 0.6573263544204795 in 47 rounds
# Started training fold 1 and class name acetylcholinesterase_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00849109	valid_1's binary_logloss: 0.0219804
# Early stopping, best iteration is:
# [3]	training's binary_logloss: 0.0198078	valid_1's binary_logloss: 0.0212296
# Fold 1 Class name acetylcholinesterase_inhibitor AUC 0.5535944959281099 in 3 rounds
# Started training fold 2 and class name acetylcholinesterase_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00840282	valid_1's binary_logloss: 0.0222109
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.0204085	valid_1's binary_logloss: 0.0213038
# Fold 2 Class name acetylcholinesterase_inhibitor AUC 0.48885144622297105 in 1 rounds
# Started training fold 3 and class name acetylcholinesterase_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00868871	valid_1's binary_logloss: 0.0211782
# Early stopping, best iteration is:
# [26]	training's binary_logloss: 0.0138031	valid_1's binary_logloss: 0.0208689
# Fold 3 Class name acetylcholinesterase_inhibitor AUC 0.6749227745015444 in 26 rounds
# Started training fold 4 and class name acetylcholinesterase_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00880105	valid_1's binary_logloss: 0.0207986
# Early stopping, best iteration is:
# [2]	training's binary_logloss: 0.0205669	valid_1's binary_logloss: 0.0200358
# Fold 4 Class name acetylcholinesterase_inhibitor AUC 0.5411977975689012 in 2 rounds
# ------Class acetylcholinesterase_inhibitor Full AUC Score  0.5977091246690166------
# Started training fold 0 and class name adenosine_receptor_agonist
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00712955	valid_1's binary_logloss: 0.0165098
# Early stopping, best iteration is:
# [22]	training's binary_logloss: 0.0118669	valid_1's binary_logloss: 0.0161085
# Fold 0 Class name adenosine_receptor_agonist AUC 0.6382575757575757 in 22 rounds
# Started training fold 1 and class name adenosine_receptor_agonist
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00742033	valid_1's binary_logloss: 0.0163533
# Early stopping, best iteration is:
# [24]	training's binary_logloss: 0.0117263	valid_1's binary_logloss: 0.0161211
# Fold 1 Class name adenosine_receptor_agonist AUC 0.6061945209672482 in 24 rounds
# Started training fold 2 and class name adenosine_receptor_agonist
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.0074737	valid_1's binary_logloss: 0.0159092
# Early stopping, best iteration is:
# [38]	training's binary_logloss: 0.00933769	valid_1's binary_logloss: 0.0158391
# Fold 2 Class name adenosine_receptor_agonist AUC 0.6353879706152433 in 38 rounds
# Started training fold 3 and class name adenosine_receptor_agonist
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00726187	valid_1's binary_logloss: 0.0161412
# Early stopping, best iteration is:
# [43]	training's binary_logloss: 0.00831045	valid_1's binary_logloss: 0.0160207
# Fold 3 Class name adenosine_receptor_agonist AUC 0.6725780532598714 in 43 rounds
# Started training fold 4 and class name adenosine_receptor_agonist
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00733753	valid_1's binary_logloss: 0.0149531
# Early stopping, best iteration is:
# [23]	training's binary_logloss: 0.0122548	valid_1's binary_logloss: 0.0148568
# Fold 4 Class name adenosine_receptor_agonist AUC 0.6211069023569024 in 23 rounds
# ------Class adenosine_receptor_agonist Full AUC Score  0.6331517333832148------
# Started training fold 0 and class name adenosine_receptor_antagonist
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.0102951	valid_1's binary_logloss: 0.0265382
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.0259331	valid_1's binary_logloss: 0.0260299
# Fold 0 Class name adenosine_receptor_antagonist AUC 0.46087024052542824 in 1 rounds
# Started training fold 1 and class name adenosine_receptor_antagonist
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.0109635	valid_1's binary_logloss: 0.0242353
# [100]	training's binary_logloss: 0.00503143	valid_1's binary_logloss: 0.0243642
# Early stopping, best iteration is:
# [68]	training's binary_logloss: 0.00802403	valid_1's binary_logloss: 0.0240576
# Fold 1 Class name adenosine_receptor_antagonist AUC 0.7928907428774297 in 68 rounds
# Started training fold 2 and class name adenosine_receptor_antagonist
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.0102116	valid_1's binary_logloss: 0.0263226
# Early stopping, best iteration is:
# [14]	training's binary_logloss: 0.0202308	valid_1's binary_logloss: 0.0257209
# Fold 2 Class name adenosine_receptor_antagonist AUC 0.614560220111831 in 14 rounds
# Started training fold 3 and class name adenosine_receptor_antagonist
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.0102349	valid_1's binary_logloss: 0.0270091
# Early stopping, best iteration is:
# [41]	training's binary_logloss: 0.0121078	valid_1's binary_logloss: 0.0268684
# Fold 3 Class name adenosine_receptor_antagonist AUC 0.6424942019818681 in 41 rounds
# Started training fold 4 and class name adenosine_receptor_antagonist
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.0104387	valid_1's binary_logloss: 0.0257778
# [100]	training's binary_logloss: 0.00475835	valid_1's binary_logloss: 0.025996
# Early stopping, best iteration is:
# [57]	training's binary_logloss: 0.00906941	valid_1's binary_logloss: 0.0257097
# Fold 4 Class name adenosine_receptor_antagonist AUC 0.5917196533395475 in 57 rounds
# ------Class adenosine_receptor_antagonist Full AUC Score  0.635331024959946------
# Started training fold 0 and class name adenylyl_cyclase_activator
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00258673	valid_1's binary_logloss: 0.00272525
# [100]	training's binary_logloss: 0.00111038	valid_1's binary_logloss: 0.0021294
# [150]	training's binary_logloss: 0.00046233	valid_1's binary_logloss: 0.00191214
# [200]	training's binary_logloss: 0.000315995	valid_1's binary_logloss: 0.00184007
# [250]	training's binary_logloss: 0.000259371	valid_1's binary_logloss: 0.0017939
# Early stopping, best iteration is:
# [227]	training's binary_logloss: 0.000266704	valid_1's binary_logloss: 0.00179101
# Fold 0 Class name adenylyl_cyclase_activator AUC 1.0 in 227 rounds
# Started training fold 1 and class name adenylyl_cyclase_activator
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.0027021	valid_1's binary_logloss: 0.00251696
# [100]	training's binary_logloss: 0.00139164	valid_1's binary_logloss: 0.00185754
# [150]	training's binary_logloss: 0.000567297	valid_1's binary_logloss: 0.00142037
# [200]	training's binary_logloss: 0.000356804	valid_1's binary_logloss: 0.00128875
# [250]	training's binary_logloss: 0.000262416	valid_1's binary_logloss: 0.00126707
# Early stopping, best iteration is:
# [246]	training's binary_logloss: 0.000265124	valid_1's binary_logloss: 0.0012631
# Fold 1 Class name adenylyl_cyclase_activator AUC 0.9997899600924175 in 246 rounds
# Started training fold 2 and class name adenylyl_cyclase_activator
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00226938	valid_1's binary_logloss: 0.0041639
# [100]	training's binary_logloss: 0.00108124	valid_1's binary_logloss: 0.00356758
# [150]	training's binary_logloss: 0.000436905	valid_1's binary_logloss: 0.00333383
# [200]	training's binary_logloss: 0.000284875	valid_1's binary_logloss: 0.00319911
# Early stopping, best iteration is:
# [196]	training's binary_logloss: 0.000293562	valid_1's binary_logloss: 0.00319607
# Fold 2 Class name adenylyl_cyclase_activator AUC 0.9957983193277311 in 196 rounds
# Started training fold 3 and class name adenylyl_cyclase_activator
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00245465	valid_1's binary_logloss: 0.00413613
# [100]	training's binary_logloss: 0.00130046	valid_1's binary_logloss: 0.00359231
# [150]	training's binary_logloss: 0.000494065	valid_1's binary_logloss: 0.00341535
# [200]	training's binary_logloss: 0.000313847	valid_1's binary_logloss: 0.00333328
# Early stopping, best iteration is:
# [186]	training's binary_logloss: 0.000352429	valid_1's binary_logloss: 0.00332817
# Fold 3 Class name adenylyl_cyclase_activator AUC 0.9961484593837535 in 186 rounds
# Started training fold 4 and class name adenylyl_cyclase_activator
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00274415	valid_1's binary_logloss: 0.00229859
# [100]	training's binary_logloss: 0.00138805	valid_1's binary_logloss: 0.00142139
# [150]	training's binary_logloss: 0.000526183	valid_1's binary_logloss: 0.000894309
# [200]	training's binary_logloss: 0.000347853	valid_1's binary_logloss: 0.000744101
# [250]	training's binary_logloss: 0.000257904	valid_1's binary_logloss: 0.00068789
# Early stopping, best iteration is:
# [247]	training's binary_logloss: 0.000257904	valid_1's binary_logloss: 0.00068789
# Fold 4 Class name adenylyl_cyclase_activator AUC 0.9998949579831933 in 247 rounds
# ------Class adenylyl_cyclase_activator Full AUC Score  0.9982669523569447------
# Started training fold 0 and class name adrenergic_receptor_agonist
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.0289219	valid_1's binary_logloss: 0.0571954
# Early stopping, best iteration is:
# [47]	training's binary_logloss: 0.0300486	valid_1's binary_logloss: 0.05712
# Fold 0 Class name adrenergic_receptor_agonist AUC 0.7007817968743856 in 47 rounds
# Started training fold 1 and class name adrenergic_receptor_agonist
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.0282613	valid_1's binary_logloss: 0.0579538
# [100]	training's binary_logloss: 0.0169833	valid_1's binary_logloss: 0.0577898
# Early stopping, best iteration is:
# [93]	training's binary_logloss: 0.0180134	valid_1's binary_logloss: 0.0577548
# Fold 1 Class name adrenergic_receptor_agonist AUC 0.7117458294990681 in 93 rounds
# Started training fold 2 and class name adrenergic_receptor_agonist
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.0282509	valid_1's binary_logloss: 0.0585181
# [100]	training's binary_logloss: 0.0158957	valid_1's binary_logloss: 0.0584807
# Early stopping, best iteration is:
# [83]	training's binary_logloss: 0.0191587	valid_1's binary_logloss: 0.0583787
# Fold 2 Class name adrenergic_receptor_agonist AUC 0.7245345791746302 in 83 rounds
# Started training fold 3 and class name adrenergic_receptor_agonist
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.0296767	valid_1's binary_logloss: 0.056728
# [100]	training's binary_logloss: 0.0169212	valid_1's binary_logloss: 0.056725
# Early stopping, best iteration is:
# [79]	training's binary_logloss: 0.020769	valid_1's binary_logloss: 0.0565047
# Fold 3 Class name adrenergic_receptor_agonist AUC 0.7334104118984135 in 79 rounds
# Started training fold 4 and class name adrenergic_receptor_agonist
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.02915	valid_1's binary_logloss: 0.0581313
# [100]	training's binary_logloss: 0.017015	valid_1's binary_logloss: 0.0582334
# Early stopping, best iteration is:
# [53]	training's binary_logloss: 0.0282482	valid_1's binary_logloss: 0.0578781
# Fold 4 Class name adrenergic_receptor_agonist AUC 0.6730309323767268 in 53 rounds
# ------Class adrenergic_receptor_agonist Full AUC Score  0.7063918148525692------
# Started training fold 0 and class name adrenergic_receptor_antagonist
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.0518736	valid_1's binary_logloss: 0.0761609
# [100]	training's binary_logloss: 0.0338257	valid_1's binary_logloss: 0.0760456
# Early stopping, best iteration is:
# [87]	training's binary_logloss: 0.0370445	valid_1's binary_logloss: 0.0759508
# Fold 0 Class name adrenergic_receptor_antagonist AUC 0.6551700656102702 in 87 rounds
# Started training fold 1 and class name adrenergic_receptor_antagonist
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.0477801	valid_1's binary_logloss: 0.0768194
# [100]	training's binary_logloss: 0.0308625	valid_1's binary_logloss: 0.077086
# Early stopping, best iteration is:
# [84]	training's binary_logloss: 0.0357358	valid_1's binary_logloss: 0.0766287
# Fold 1 Class name adrenergic_receptor_antagonist AUC 0.6378230180724318 in 84 rounds
# Started training fold 2 and class name adrenergic_receptor_antagonist
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.0516787	valid_1's binary_logloss: 0.0753521
# [100]	training's binary_logloss: 0.034314	valid_1's binary_logloss: 0.0743259
# [150]	training's binary_logloss: 0.0240645	valid_1's binary_logloss: 0.0747593
# Early stopping, best iteration is:
# [105]	training's binary_logloss: 0.0330333	valid_1's binary_logloss: 0.0742599
# Fold 2 Class name adrenergic_receptor_antagonist AUC 0.6945895213055733 in 105 rounds
# Started training fold 3 and class name adrenergic_receptor_antagonist
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.0534117	valid_1's binary_logloss: 0.0765613
# [100]	training's binary_logloss: 0.0346124	valid_1's binary_logloss: 0.0762582
# Early stopping, best iteration is:
# [79]	training's binary_logloss: 0.041147	valid_1's binary_logloss: 0.0761736
# Fold 3 Class name adrenergic_receptor_antagonist AUC 0.6522803713967644 in 79 rounds
# Started training fold 4 and class name adrenergic_receptor_antagonist
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.0489532	valid_1's binary_logloss: 0.0760439
# [100]	training's binary_logloss: 0.0316533	valid_1's binary_logloss: 0.0760813
# Early stopping, best iteration is:
# [67]	training's binary_logloss: 0.0419038	valid_1's binary_logloss: 0.0758169
# Fold 4 Class name adrenergic_receptor_antagonist AUC 0.664587775408671 in 67 rounds
# ------Class adrenergic_receptor_antagonist Full AUC Score  0.6605507944629203------
# Started training fold 0 and class name akt_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00662818	valid_1's binary_logloss: 0.0149621
# [100]	training's binary_logloss: 0.00254925	valid_1's binary_logloss: 0.0152003
# Early stopping, best iteration is:
# [63]	training's binary_logloss: 0.00508858	valid_1's binary_logloss: 0.0147653
# Fold 0 Class name akt_inhibitor AUC 0.7610526315789474 in 63 rounds
# Started training fold 1 and class name akt_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.0065967	valid_1's binary_logloss: 0.0136217
# [100]	training's binary_logloss: 0.00253236	valid_1's binary_logloss: 0.0128229
# [150]	training's binary_logloss: 0.00133129	valid_1's binary_logloss: 0.0130192
# Early stopping, best iteration is:
# [108]	training's binary_logloss: 0.00224681	valid_1's binary_logloss: 0.0127577
# Fold 1 Class name akt_inhibitor AUC 0.8915951417004049 in 108 rounds
# Started training fold 2 and class name akt_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00602424	valid_1's binary_logloss: 0.0138309
# [100]	training's binary_logloss: 0.00236547	valid_1's binary_logloss: 0.0139384
# Early stopping, best iteration is:
# [68]	training's binary_logloss: 0.00414213	valid_1's binary_logloss: 0.0136846
# Fold 2 Class name akt_inhibitor AUC 0.73965991902834 in 68 rounds
# Started training fold 3 and class name akt_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00657573	valid_1's binary_logloss: 0.0139837
# [100]	training's binary_logloss: 0.0024612	valid_1's binary_logloss: 0.0132277
# Early stopping, best iteration is:
# [95]	training's binary_logloss: 0.00268333	valid_1's binary_logloss: 0.0131321
# Fold 3 Class name akt_inhibitor AUC 0.9461841590710826 in 95 rounds
# Started training fold 4 and class name akt_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00634535	valid_1's binary_logloss: 0.0135151
# [100]	training's binary_logloss: 0.00242112	valid_1's binary_logloss: 0.0133337
# Early stopping, best iteration is:
# [88]	training's binary_logloss: 0.00295586	valid_1's binary_logloss: 0.0132585
# Fold 4 Class name akt_inhibitor AUC 0.8330336751056902 in 88 rounds
# ------Class akt_inhibitor Full AUC Score  0.8404848127561619------
# Started training fold 0 and class name aldehyde_dehydrogenase_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00198062	valid_1's binary_logloss: 0.0015271
# [100]	training's binary_logloss: 0.00113186	valid_1's binary_logloss: 0.00122454
# [150]	training's binary_logloss: 0.000627428	valid_1's binary_logloss: 0.00111063
# [200]	training's binary_logloss: 0.000361676	valid_1's binary_logloss: 0.0010225
# Early stopping, best iteration is:
# [197]	training's binary_logloss: 0.000371733	valid_1's binary_logloss: 0.00102232
# Fold 0 Class name aldehyde_dehydrogenase_inhibitor AUC 0.999790004199916 in 197 rounds
# Started training fold 1 and class name aldehyde_dehydrogenase_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00198047	valid_1's binary_logloss: 0.00160832
# [100]	training's binary_logloss: 0.0011513	valid_1's binary_logloss: 0.00115605
# [150]	training's binary_logloss: 0.000648293	valid_1's binary_logloss: 0.00101695
# [200]	training's binary_logloss: 0.000375212	valid_1's binary_logloss: 0.000912957
# [250]	training's binary_logloss: 0.000306204	valid_1's binary_logloss: 0.000900258
# Early stopping, best iteration is:
# [214]	training's binary_logloss: 0.000330201	valid_1's binary_logloss: 0.000896637
# Fold 1 Class name aldehyde_dehydrogenase_inhibitor AUC 1.0 in 214 rounds
# Started training fold 2 and class name aldehyde_dehydrogenase_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.0018852	valid_1's binary_logloss: 0.00322311
# [100]	training's binary_logloss: 0.00134246	valid_1's binary_logloss: 0.00274505
# [150]	training's binary_logloss: 0.000804473	valid_1's binary_logloss: 0.00223261
# [200]	training's binary_logloss: 0.000383541	valid_1's binary_logloss: 0.00211916
# Early stopping, best iteration is:
# [174]	training's binary_logloss: 0.00056672	valid_1's binary_logloss: 0.00200355
# Fold 2 Class name aldehyde_dehydrogenase_inhibitor AUC 1.0 in 174 rounds
# Started training fold 3 and class name aldehyde_dehydrogenase_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00188517	valid_1's binary_logloss: 0.00335261
# [100]	training's binary_logloss: 0.00134246	valid_1's binary_logloss: 0.00306702
# [150]	training's binary_logloss: 0.000804556	valid_1's binary_logloss: 0.0027916
# [200]	training's binary_logloss: 0.000379614	valid_1's binary_logloss: 0.00270049
# [250]	training's binary_logloss: 0.000352282	valid_1's binary_logloss: 0.00263757
# Early stopping, best iteration is:
# [213]	training's binary_logloss: 0.000352282	valid_1's binary_logloss: 0.00263757
# Fold 3 Class name aldehyde_dehydrogenase_inhibitor AUC 0.9913883637891199 in 213 rounds
# Started training fold 4 and class name aldehyde_dehydrogenase_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00198035	valid_1's binary_logloss: 0.00156944
# [100]	training's binary_logloss: 0.00116618	valid_1's binary_logloss: 0.00110422
# [150]	training's binary_logloss: 0.000667662	valid_1's binary_logloss: 0.000918755
# Early stopping, best iteration is:
# [141]	training's binary_logloss: 0.00074203	valid_1's binary_logloss: 0.000916089
# Fold 4 Class name aldehyde_dehydrogenase_inhibitor AUC 1.0 in 141 rounds
# ------Class aldehyde_dehydrogenase_inhibitor Full AUC Score  0.9965016291726925------
# Started training fold 0 and class name alk_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00528582	valid_1's binary_logloss: 0.0105578
# [100]	training's binary_logloss: 0.00201494	valid_1's binary_logloss: 0.0103909
# [150]	training's binary_logloss: 0.00106195	valid_1's binary_logloss: 0.0105331
# Early stopping, best iteration is:
# [111]	training's binary_logloss: 0.00169096	valid_1's binary_logloss: 0.0103773
# Fold 0 Class name alk_inhibitor AUC 0.8634069400630915 in 111 rounds
# Started training fold 1 and class name alk_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00503774	valid_1's binary_logloss: 0.00966809
# [100]	training's binary_logloss: 0.00187037	valid_1's binary_logloss: 0.00968686
# Early stopping, best iteration is:
# [62]	training's binary_logloss: 0.00390511	valid_1's binary_logloss: 0.00961631
# Fold 1 Class name alk_inhibitor AUC 0.9175078864353312 in 62 rounds
# Started training fold 2 and class name alk_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00507578	valid_1's binary_logloss: 0.012268
# Early stopping, best iteration is:
# [35]	training's binary_logloss: 0.0068457	valid_1's binary_logloss: 0.0120733
# Fold 2 Class name alk_inhibitor AUC 0.8685551348571964 in 35 rounds
# Started training fold 3 and class name alk_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00544156	valid_1's binary_logloss: 0.0111008
# [100]	training's binary_logloss: 0.00199159	valid_1's binary_logloss: 0.0112809
# Early stopping, best iteration is:
# [58]	training's binary_logloss: 0.00459613	valid_1's binary_logloss: 0.0110499
# Fold 3 Class name alk_inhibitor AUC 0.8764549151591642 in 58 rounds
# Started training fold 4 and class name alk_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.005456	valid_1's binary_logloss: 0.00911311
# [100]	training's binary_logloss: 0.00200842	valid_1's binary_logloss: 0.0088732
# Early stopping, best iteration is:
# [74]	training's binary_logloss: 0.0032339	valid_1's binary_logloss: 0.00881599
# Fold 4 Class name alk_inhibitor AUC 0.9820677324358434 in 74 rounds
# ------Class alk_inhibitor Full AUC Score  0.8841564305345224------
# Started training fold 0 and class name ampk_activator
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00325864	valid_1's binary_logloss: 0.0037502
# Early stopping, best iteration is:
# [11]	training's binary_logloss: 0.00424249	valid_1's binary_logloss: 0.00364748
# Fold 0 Class name ampk_activator AUC 0.7292585591262339 in 11 rounds
# Started training fold 1 and class name ampk_activator
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00315633	valid_1's binary_logloss: 0.00358126
# [100]	training's binary_logloss: 0.00197038	valid_1's binary_logloss: 0.00359983
# Early stopping, best iteration is:
# [64]	training's binary_logloss: 0.00284125	valid_1's binary_logloss: 0.00352001
# Fold 1 Class name ampk_activator AUC 0.6490233144297417 in 64 rounds
# Started training fold 2 and class name ampk_activator
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00313538	valid_1's binary_logloss: 0.00555237
# Early stopping, best iteration is:
# [4]	training's binary_logloss: 0.00399206	valid_1's binary_logloss: 0.0052958
# Fold 2 Class name ampk_activator AUC 0.4882703081232493 in 4 rounds
# Started training fold 3 and class name ampk_activator
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00310764	valid_1's binary_logloss: 0.00552465
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.00406996	valid_1's binary_logloss: 0.00529417
# Fold 3 Class name ampk_activator AUC 0.5429271708683473 in 1 rounds
# Started training fold 4 and class name ampk_activator
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00339993	valid_1's binary_logloss: 0.00374766
# Early stopping, best iteration is:
# [11]	training's binary_logloss: 0.00421418	valid_1's binary_logloss: 0.00365948
# Fold 4 Class name ampk_activator AUC 0.6147584033613446 in 11 rounds
# ------Class ampk_activator Full AUC Score  0.5695389743158839------
# Started training fold 0 and class name analgesic
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00313171	valid_1's binary_logloss: 0.00392012
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.00445693	valid_1's binary_logloss: 0.00370918
# Fold 0 Class name analgesic AUC 0.2913253518168452 in 1 rounds
# Started training fold 1 and class name analgesic
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00308715	valid_1's binary_logloss: 0.00367822
# Early stopping, best iteration is:
# [28]	training's binary_logloss: 0.00362966	valid_1's binary_logloss: 0.00365641
# Fold 1 Class name analgesic AUC 0.71686620457887 in 28 rounds
# Started training fold 2 and class name analgesic
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00295652	valid_1's binary_logloss: 0.00533739
# Early stopping, best iteration is:
# [7]	training's binary_logloss: 0.00393082	valid_1's binary_logloss: 0.00525648
# Fold 2 Class name analgesic AUC 0.6602240896358543 in 7 rounds
# Started training fold 3 and class name analgesic
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00306423	valid_1's binary_logloss: 0.00496659
# [100]	training's binary_logloss: 0.00215393	valid_1's binary_logloss: 0.00481132
# Early stopping, best iteration is:
# [85]	training's binary_logloss: 0.00242933	valid_1's binary_logloss: 0.00475563
# Fold 3 Class name analgesic AUC 0.9070728291316528 in 85 rounds
# Started training fold 4 and class name analgesic
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00314572	valid_1's binary_logloss: 0.00381677
# Early stopping, best iteration is:
# [3]	training's binary_logloss: 0.00441706	valid_1's binary_logloss: 0.0036717
# Fold 4 Class name analgesic AUC 0.7447478991596639 in 3 rounds
# ------Class analgesic Full AUC Score  0.7063236982886593------
# Started training fold 0 and class name androgen_receptor_agonist
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00659472	valid_1's binary_logloss: 0.0139683
# Early stopping, best iteration is:
# [5]	training's binary_logloss: 0.0138267	valid_1's binary_logloss: 0.0136944
# Fold 0 Class name androgen_receptor_agonist AUC 0.567779180105642 in 5 rounds
# Started training fold 1 and class name androgen_receptor_agonist
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00649661	valid_1's binary_logloss: 0.0154951
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.0141482	valid_1's binary_logloss: 0.0150755
# Fold 1 Class name androgen_receptor_agonist AUC 0.4998211655796339 in 1 rounds
# Started training fold 2 and class name androgen_receptor_agonist
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00628886	valid_1's binary_logloss: 0.0152503
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.0142069	valid_1's binary_logloss: 0.0150343
# Fold 2 Class name androgen_receptor_agonist AUC 0.5510098884914791 in 1 rounds
# Started training fold 3 and class name androgen_receptor_agonist
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00649665	valid_1's binary_logloss: 0.0146303
# Early stopping, best iteration is:
# [27]	training's binary_logloss: 0.00992727	valid_1's binary_logloss: 0.0145469
# Fold 3 Class name androgen_receptor_agonist AUC 0.7308857563644015 in 27 rounds
# Started training fold 4 and class name androgen_receptor_agonist
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00691633	valid_1's binary_logloss: 0.0132395
# Early stopping, best iteration is:
# [40]	training's binary_logloss: 0.00841469	valid_1's binary_logloss: 0.0130875
# Fold 4 Class name androgen_receptor_agonist AUC 0.721742992729738 in 40 rounds
# ------Class androgen_receptor_agonist Full AUC Score  0.6216803066004657------
# Started training fold 0 and class name androgen_receptor_antagonist
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00988741	valid_1's binary_logloss: 0.0254058
# Early stopping, best iteration is:
# [3]	training's binary_logloss: 0.0235371	valid_1's binary_logloss: 0.0247618
# Fold 0 Class name androgen_receptor_antagonist AUC 0.6150509308043556 in 3 rounds
# Started training fold 1 and class name androgen_receptor_antagonist
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.0102228	valid_1's binary_logloss: 0.0246087
# [100]	training's binary_logloss: 0.00462462	valid_1's binary_logloss: 0.0244255
# Early stopping, best iteration is:
# [82]	training's binary_logloss: 0.00595004	valid_1's binary_logloss: 0.0242328
# Fold 1 Class name androgen_receptor_antagonist AUC 0.7051867462826367 in 82 rounds
# Started training fold 2 and class name androgen_receptor_antagonist
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00981941	valid_1's binary_logloss: 0.0251361
# Early stopping, best iteration is:
# [16]	training's binary_logloss: 0.0192736	valid_1's binary_logloss: 0.0245502
# Fold 2 Class name androgen_receptor_antagonist AUC 0.6427233345041564 in 16 rounds
# Started training fold 3 and class name androgen_receptor_antagonist
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.0102246	valid_1's binary_logloss: 0.0253052
# Early stopping, best iteration is:
# [12]	training's binary_logloss: 0.0205707	valid_1's binary_logloss: 0.0247069
# Fold 3 Class name androgen_receptor_antagonist AUC 0.593677555321391 in 12 rounds
# Started training fold 4 and class name androgen_receptor_antagonist
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.0103273	valid_1's binary_logloss: 0.0237571
# Early stopping, best iteration is:
# [26]	training's binary_logloss: 0.0166197	valid_1's binary_logloss: 0.0235426
# Fold 4 Class name androgen_receptor_antagonist AUC 0.6229839459492964 in 26 rounds
# ------Class androgen_receptor_antagonist Full AUC Score  0.6181586767857354------
# Started training fold 0 and class name anesthetic_-_local
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00894802	valid_1's binary_logloss: 0.0218173
# [100]	training's binary_logloss: 0.00394694	valid_1's binary_logloss: 0.0219434
# Early stopping, best iteration is:
# [65]	training's binary_logloss: 0.00677812	valid_1's binary_logloss: 0.021614
# Fold 0 Class name anesthetic_-_local AUC 0.7225879502843902 in 65 rounds
# Started training fold 1 and class name anesthetic_-_local
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00905527	valid_1's binary_logloss: 0.0222368
# [100]	training's binary_logloss: 0.0041413	valid_1's binary_logloss: 0.0229158
# Early stopping, best iteration is:
# [55]	training's binary_logloss: 0.00822255	valid_1's binary_logloss: 0.022211
# Fold 1 Class name anesthetic_-_local AUC 0.6727143459026754 in 55 rounds
# Started training fold 2 and class name anesthetic_-_local
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00883826	valid_1's binary_logloss: 0.0229852
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.0221829	valid_1's binary_logloss: 0.0225107
# Fold 2 Class name anesthetic_-_local AUC 0.5077351485148515 in 1 rounds
# Started training fold 3 and class name anesthetic_-_local
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00925875	valid_1's binary_logloss: 0.023379
# Early stopping, best iteration is:
# [3]	training's binary_logloss: 0.0216185	valid_1's binary_logloss: 0.0225219
# Fold 3 Class name anesthetic_-_local AUC 0.4458605435011586 in 3 rounds
# Started training fold 4 and class name anesthetic_-_local
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00932075	valid_1's binary_logloss: 0.0223281
# Early stopping, best iteration is:
# [19]	training's binary_logloss: 0.0167449	valid_1's binary_logloss: 0.0221313
# Fold 4 Class name anesthetic_-_local AUC 0.6277523177412557 in 19 rounds
# ------Class anesthetic_-_local Full AUC Score  0.6159446890536782------
# Started training fold 0 and class name angiogenesis_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00564277	valid_1's binary_logloss: 0.0107251
# Early stopping, best iteration is:
# [31]	training's binary_logloss: 0.00775386	valid_1's binary_logloss: 0.0106449
# Fold 0 Class name angiogenesis_inhibitor AUC 0.7328186951820256 in 31 rounds
# Started training fold 1 and class name angiogenesis_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00533904	valid_1's binary_logloss: 0.011381
# Early stopping, best iteration is:
# [6]	training's binary_logloss: 0.0106014	valid_1's binary_logloss: 0.010909
# Fold 1 Class name angiogenesis_inhibitor AUC 0.6396882133845969 in 6 rounds
# Started training fold 2 and class name angiogenesis_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.0053857	valid_1's binary_logloss: 0.0115066
# Early stopping, best iteration is:
# [5]	training's binary_logloss: 0.0107535	valid_1's binary_logloss: 0.0110329
# Fold 2 Class name angiogenesis_inhibitor AUC 0.5624474348191757 in 5 rounds
# Started training fold 3 and class name angiogenesis_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00546135	valid_1's binary_logloss: 0.0124899
# Early stopping, best iteration is:
# [26]	training's binary_logloss: 0.00791932	valid_1's binary_logloss: 0.012309
# Fold 3 Class name angiogenesis_inhibitor AUC 0.5627234490010515 in 26 rounds
# Started training fold 4 and class name angiogenesis_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00530361	valid_1's binary_logloss: 0.0115547
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.0112697	valid_1's binary_logloss: 0.0110499
# Fold 4 Class name angiogenesis_inhibitor AUC 0.4953732912723449 in 1 rounds
# ------Class angiogenesis_inhibitor Full AUC Score  0.6073751647180867------
# Started training fold 0 and class name angiotensin_receptor_antagonist
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00584634	valid_1's binary_logloss: 0.0109994
# Early stopping, best iteration is:
# [29]	training's binary_logloss: 0.00822637	valid_1's binary_logloss: 0.0107588
# Fold 0 Class name angiotensin_receptor_antagonist AUC 0.6701009251471824 in 29 rounds
# Started training fold 1 and class name angiotensin_receptor_antagonist
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00556857	valid_1's binary_logloss: 0.0112451
# Early stopping, best iteration is:
# ...
# [50]	training's binary_logloss: 0.0147539	valid_1's binary_logloss: 0.0312471
# [100]	training's binary_logloss: 0.00614344	valid_1's binary_logloss: 0.028484
# [150]	training's binary_logloss: 0.0030978	valid_1's binary_logloss: 0.027898
# Early stopping, best iteration is:
# [127]	training's binary_logloss: 0.00410402	valid_1's binary_logloss: 0.027786
# Fold 3 Class name tubulin_inhibitor AUC 0.9532181049159396 in 127 rounds
# Started training fold 4 and class name tubulin_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.0146362	valid_1's binary_logloss: 0.030158
# [100]	training's binary_logloss: 0.00602041	valid_1's binary_logloss: 0.0275907
# [150]	training's binary_logloss: 0.00294422	valid_1's binary_logloss: 0.027772
# Early stopping, best iteration is:
# [124]	training's binary_logloss: 0.00413685	valid_1's binary_logloss: 0.0275031
# Fold 4 Class name tubulin_inhibitor AUC 0.9469356870931674 in 124 rounds
# ------Class tubulin_inhibitor Full AUC Score  0.9632959605503728------
# Started training fold 0 and class name tyrosine_kinase_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00865482	valid_1's binary_logloss: 0.0197677
# Early stopping, best iteration is:
# [28]	training's binary_logloss: 0.0138376	valid_1's binary_logloss: 0.0196161
# Fold 0 Class name tyrosine_kinase_inhibitor AUC 0.6534307974611197 in 28 rounds
# Started training fold 1 and class name tyrosine_kinase_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00847208	valid_1's binary_logloss: 0.021089
# [100]	training's binary_logloss: 0.00338082	valid_1's binary_logloss: 0.0212508
# Early stopping, best iteration is:
# [64]	training's binary_logloss: 0.00636768	valid_1's binary_logloss: 0.0209884
# Fold 1 Class name tyrosine_kinase_inhibitor AUC 0.600940746981185 in 64 rounds
# Started training fold 2 and class name tyrosine_kinase_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00844189	valid_1's binary_logloss: 0.0202629
# [100]	training's binary_logloss: 0.00343712	valid_1's binary_logloss: 0.0207552
# Early stopping, best iteration is:
# [53]	training's binary_logloss: 0.00792962	valid_1's binary_logloss: 0.0202445
# Fold 2 Class name tyrosine_kinase_inhibitor AUC 0.6792052794158944 in 53 rounds
# Started training fold 3 and class name tyrosine_kinase_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00821515	valid_1's binary_logloss: 0.020817
# [100]	training's binary_logloss: 0.00338514	valid_1's binary_logloss: 0.0213714
# Early stopping, best iteration is:
# [52]	training's binary_logloss: 0.00789731	valid_1's binary_logloss: 0.0207405
# Fold 3 Class name tyrosine_kinase_inhibitor AUC 0.6718477955630442 in 52 rounds
# Started training fold 4 and class name tyrosine_kinase_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00865756	valid_1's binary_logloss: 0.0190396
# [100]	training's binary_logloss: 0.00345032	valid_1's binary_logloss: 0.0188588
# Early stopping, best iteration is:
# [87]	training's binary_logloss: 0.00423617	valid_1's binary_logloss: 0.0187193
# Fold 4 Class name tyrosine_kinase_inhibitor AUC 0.7248766397881815 in 87 rounds
# ------Class tyrosine_kinase_inhibitor Full AUC Score  0.6616234674076925------
# Started training fold 0 and class name ubiquitin_specific_protease_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00188568	valid_1's binary_logloss: 0.00202928
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.00241568	valid_1's binary_logloss: 0.00198489
# Fold 0 Class name ubiquitin_specific_protease_inhibitor AUC 0.8021839563208736 in 1 rounds
# Started training fold 1 and class name ubiquitin_specific_protease_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00188621	valid_1's binary_logloss: 0.00193985
# [100]	training's binary_logloss: 0.0013662	valid_1's binary_logloss: 0.00197576
# Early stopping, best iteration is:
# [55]	training's binary_logloss: 0.00183219	valid_1's binary_logloss: 0.0019112
# Fold 1 Class name ubiquitin_specific_protease_inhibitor AUC 0.8460730785384292 in 55 rounds
# Started training fold 2 and class name ubiquitin_specific_protease_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00188708	valid_1's binary_logloss: 0.00173489
# [100]	training's binary_logloss: 0.00141588	valid_1's binary_logloss: 0.00171869
# [150]	training's binary_logloss: 0.00101964	valid_1's binary_logloss: 0.00164513
# [200]	training's binary_logloss: 0.000702471	valid_1's binary_logloss: 0.00161058
# [250]	training's binary_logloss: 0.000490023	valid_1's binary_logloss: 0.00158124
# Early stopping, best iteration is:
# [220]	training's binary_logloss: 0.000600646	valid_1's binary_logloss: 0.0015699
# Fold 2 Class name ubiquitin_specific_protease_inhibitor AUC 0.9874002519949601 in 220 rounds
# Started training fold 3 and class name ubiquitin_specific_protease_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00355613	valid_1's binary_logloss: 0.00711184
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.00355613	valid_1's binary_logloss: 0.00711184
# Fold 3 Class name ubiquitin_specific_protease_inhibitor AUC 0.5 in 1 rounds
# Started training fold 4 and class name ubiquitin_specific_protease_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00188584	valid_1's binary_logloss: 0.00193778
# [100]	training's binary_logloss: 0.00134517	valid_1's binary_logloss: 0.00203454
# Early stopping, best iteration is:
# [50]	training's binary_logloss: 0.00188584	valid_1's binary_logloss: 0.00193778
# Fold 4 Class name ubiquitin_specific_protease_inhibitor AUC 0.8202058391094309 in 50 rounds
# ------Class ubiquitin_specific_protease_inhibitor Full AUC Score  0.7338989695340501------
# Started training fold 0 and class name vegfr_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.0123933	valid_1's binary_logloss: 0.0266848
# [100]	training's binary_logloss: 0.00523566	valid_1's binary_logloss: 0.0258053
# Early stopping, best iteration is:
# [85]	training's binary_logloss: 0.00660638	valid_1's binary_logloss: 0.0256574
# Fold 0 Class name vegfr_inhibitor AUC 0.892490639732315 in 85 rounds
# Started training fold 1 and class name vegfr_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.012333	valid_1's binary_logloss: 0.0263287
# [100]	training's binary_logloss: 0.00561368	valid_1's binary_logloss: 0.0250222
# [150]	training's binary_logloss: 0.00303828	valid_1's binary_logloss: 0.0254409
# Early stopping, best iteration is:
# [101]	training's binary_logloss: 0.00553787	valid_1's binary_logloss: 0.0249972
# Fold 1 Class name vegfr_inhibitor AUC 0.8802134514198997 in 101 rounds
# Started training fold 2 and class name vegfr_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.0120866	valid_1's binary_logloss: 0.0282903
# [100]	training's binary_logloss: 0.00524273	valid_1's binary_logloss: 0.0283462
# Early stopping, best iteration is:
# [70]	training's binary_logloss: 0.00858414	valid_1's binary_logloss: 0.0279069
# Fold 2 Class name vegfr_inhibitor AUC 0.9090965631336061 in 70 rounds
# Started training fold 3 and class name vegfr_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.0122327	valid_1's binary_logloss: 0.0283649
# [100]	training's binary_logloss: 0.00545866	valid_1's binary_logloss: 0.0278391
# Early stopping, best iteration is:
# [82]	training's binary_logloss: 0.00720291	valid_1's binary_logloss: 0.0275713
# Fold 3 Class name vegfr_inhibitor AUC 0.8902951749530431 in 82 rounds
# Started training fold 4 and class name vegfr_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.0125805	valid_1's binary_logloss: 0.0269436
# [100]	training's binary_logloss: 0.00554909	valid_1's binary_logloss: 0.0260841
# Early stopping, best iteration is:
# [92]	training's binary_logloss: 0.00624384	valid_1's binary_logloss: 0.025971
# Fold 4 Class name vegfr_inhibitor AUC 0.9378359211704986 in 92 rounds
# ------Class vegfr_inhibitor Full AUC Score  0.9001127011454217------
# Started training fold 0 and class name vitamin_b
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00501671	valid_1's binary_logloss: 0.00846101
# Early stopping, best iteration is:
# [7]	training's binary_logloss: 0.00812268	valid_1's binary_logloss: 0.00822606
# Fold 0 Class name vitamin_b AUC 0.6051702395964692 in 7 rounds
# Started training fold 1 and class name vitamin_b
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.0048755	valid_1's binary_logloss: 0.00846341
# Early stopping, best iteration is:
# [13]	training's binary_logloss: 0.00763979	valid_1's binary_logloss: 0.00808685
# Fold 1 Class name vitamin_b AUC 0.7291719209751997 in 13 rounds
# Started training fold 2 and class name vitamin_b
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00506447	valid_1's binary_logloss: 0.00795903
# Early stopping, best iteration is:
# [49]	training's binary_logloss: 0.00512286	valid_1's binary_logloss: 0.00793316
# Fold 2 Class name vitamin_b AUC 0.6738545607398067 in 49 rounds
# Started training fold 3 and class name vitamin_b
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00495057	valid_1's binary_logloss: 0.00970393
# Early stopping, best iteration is:
# [18]	training's binary_logloss: 0.00701518	valid_1's binary_logloss: 0.00950738
# Fold 3 Class name vitamin_b AUC 0.7060472286455048 in 18 rounds
# Started training fold 4 and class name vitamin_b
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.0049584	valid_1's binary_logloss: 0.00806891
# Early stopping, best iteration is:
# [45]	training's binary_logloss: 0.00532821	valid_1's binary_logloss: 0.00803452
# Fold 4 Class name vitamin_b AUC 0.7051082615093547 in 45 rounds
# ------Class vitamin_b Full AUC Score  0.6704705669309671------
# Started training fold 0 and class name vitamin_d_receptor_agonist
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.0038766	valid_1's binary_logloss: 0.00888337
# [100]	training's binary_logloss: 0.00131281	valid_1's binary_logloss: 0.00863927
# Early stopping, best iteration is:
# [80]	training's binary_logloss: 0.0019116	valid_1's binary_logloss: 0.00855868
# Fold 0 Class name vitamin_d_receptor_agonist AUC 0.877707676130389 in 80 rounds
# Started training fold 1 and class name vitamin_d_receptor_agonist
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00392853	valid_1's binary_logloss: 0.00700697
# [100]	training's binary_logloss: 0.00144689	valid_1's binary_logloss: 0.00612471
# [150]	training's binary_logloss: 0.000733579	valid_1's binary_logloss: 0.00581809
# [200]	training's binary_logloss: 0.000493147	valid_1's binary_logloss: 0.00567276
# [250]	training's binary_logloss: 0.000380377	valid_1's binary_logloss: 0.00557119
# [300]	training's binary_logloss: 0.000331035	valid_1's binary_logloss: 0.00553921
# [350]	training's binary_logloss: 0.000295149	valid_1's binary_logloss: 0.00550943
# [400]	training's binary_logloss: 0.00026587	valid_1's binary_logloss: 0.00547191
# [450]	training's binary_logloss: 0.000241945	valid_1's binary_logloss: 0.00547003
# Early stopping, best iteration is:
# [418]	training's binary_logloss: 0.000256668	valid_1's binary_logloss: 0.00546015
# Fold 1 Class name vitamin_d_receptor_agonist AUC 0.9822029442691904 in 418 rounds
# Started training fold 2 and class name vitamin_d_receptor_agonist
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00381276	valid_1's binary_logloss: 0.00698625
# [100]	training's binary_logloss: 0.00133535	valid_1's binary_logloss: 0.00627443
# [150]	training's binary_logloss: 0.000701067	valid_1's binary_logloss: 0.00623122
# [200]	training's binary_logloss: 0.000477428	valid_1's binary_logloss: 0.00617608
# Early stopping, best iteration is:
# [189]	training's binary_logloss: 0.000512683	valid_1's binary_logloss: 0.00612773
# Fold 2 Class name vitamin_d_receptor_agonist AUC 0.9269978969505783 in 189 rounds
# Started training fold 3 and class name vitamin_d_receptor_agonist
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00401471	valid_1's binary_logloss: 0.00658718
# [100]	training's binary_logloss: 0.0013582	valid_1's binary_logloss: 0.00568606
# [150]	training's binary_logloss: 0.00068003	valid_1's binary_logloss: 0.00568808
# Early stopping, best iteration is:
# [121]	training's binary_logloss: 0.000965504	valid_1's binary_logloss: 0.00562035
# Fold 3 Class name vitamin_d_receptor_agonist AUC 0.8332018927444796 in 121 rounds
# Started training fold 4 and class name vitamin_d_receptor_agonist
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00373666	valid_1's binary_logloss: 0.0077329
# [100]	training's binary_logloss: 0.00136859	valid_1's binary_logloss: 0.00715812
# [150]	training's binary_logloss: 0.000716029	valid_1's binary_logloss: 0.00696679
# [200]	training's binary_logloss: 0.000477709	valid_1's binary_logloss: 0.00700475
# Early stopping, best iteration is:
# [164]	training's binary_logloss: 0.000621579	valid_1's binary_logloss: 0.00693523
# Fold 4 Class name vitamin_d_receptor_agonist AUC 0.9768063692353913 in 164 rounds
# ------Class vitamin_d_receptor_agonist Full AUC Score  0.9157194855617569------
# Started training fold 0 and class name wnt_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00502789	valid_1's binary_logloss: 0.00951657
# Early stopping, best iteration is:
# [21]	training's binary_logloss: 0.00761794	valid_1's binary_logloss: 0.00943751
# Fold 0 Class name wnt_inhibitor AUC 0.7269637726858664 in 21 rounds
# Started training fold 1 and class name wnt_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00514027	valid_1's binary_logloss: 0.00969193
# Early stopping, best iteration is:
# [16]	training's binary_logloss: 0.008176	valid_1's binary_logloss: 0.00955569
# Fold 1 Class name wnt_inhibitor AUC 0.6552799383364867 in 16 rounds
# Started training fold 2 and class name wnt_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00520544	valid_1's binary_logloss: 0.00948209
# [100]	training's binary_logloss: 0.00198599	valid_1's binary_logloss: 0.00967265
# Early stopping, best iteration is:
# [54]	training's binary_logloss: 0.00491236	valid_1's binary_logloss: 0.00943627
# Fold 2 Class name wnt_inhibitor AUC 0.6746548945413776 in 54 rounds
# Started training fold 3 and class name wnt_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00593216	valid_1's binary_logloss: 0.0102111
# Early stopping, best iteration is:
# [2]	training's binary_logloss: 0.0095536	valid_1's binary_logloss: 0.00967123
# Fold 3 Class name wnt_inhibitor AUC 0.4637376497792726 in 2 rounds
# Started training fold 4 and class name wnt_inhibitor
# Training until validation scores don't improve for 50 rounds
# [50]	training's binary_logloss: 0.00522409	valid_1's binary_logloss: 0.00971239
# Early stopping, best iteration is:
# [3]	training's binary_logloss: 0.00945731	valid_1's binary_logloss: 0.00963812
# Fold 4 Class name wnt_inhibitor AUC 0.5905347631062519 in 3 rounds
# ------Class wnt_inhibitor Full AUC Score  0.648637038905707------
# Total CV Score 0.7399060873338995

# %%
sample_submission.head()
# Out:
#          sig_id  5-alpha_reductase_inhibitor  11-beta-hsd1_inhibitor  \
# 0  id_0004d9e33                     0.000458                0.001120
# 1  id_001897cda                     0.000218                0.000932
# 2  id_002429b5b                     0.000214                0.000810
# 3  id_00276f245                     0.000276                0.000811
# 4  id_0027f1083                     0.000480                0.001178
#
#    acat_inhibitor  acetylcholine_receptor_agonist  \
# 0        0.002109                        0.008193
# 1        0.001908                        0.007317
# 2        0.001796                        0.005942
# 3        0.001786                        0.007502
# 4        0.002163                        0.010231
#
#    acetylcholine_receptor_antagonist  acetylcholinesterase_inhibitor  \
# 0                           0.020366                        0.023298
# 1                           0.014264                        0.017479
# 2                           0.011533                        0.014131
# 3                           0.016022                        0.018984
# 4                           0.025535                        0.027825
#
#    adenosine_receptor_agonist  adenosine_receptor_antagonist  \
# 0                    0.024943                       0.029139
# 1                    0.018834                       0.023750
# 2                    0.016366                       0.019555
# 3                    0.020514                       0.024184
# 4                    0.029834                       0.032979
#
#    adenylyl_cyclase_activator  ...  tropomyosin_receptor_kinase_inhibitor  \
# 0                    0.029178  ...                               0.435903
# 1                    0.023844  ...                               0.430400
# 2                    0.019566  ...                               0.282484
# 3                    0.024197  ...                               0.354488
# 4                    0.033004  ...                               0.403779
#
#    trpv_agonist  trpv_antagonist  tubulin_inhibitor  \
# 0      0.436538         0.438527           0.439102
# 1      0.430896         0.433148           0.433645
# 2      0.282819         0.284993           0.285571
# 3      0.354823         0.356765           0.357920
# 4      0.404125         0.406281           0.407457
#
#    tyrosine_kinase_inhibitor  ubiquitin_specific_protease_inhibitor  \
# 0                   0.440301                               0.440495
# 1                   0.445635                               0.445851
# 2                   0.287364                               0.287547
# 3                   0.359606                               0.359800
# 4                   0.408821                               0.409031
#
#    vegfr_inhibitor  vitamin_b  vitamin_d_receptor_agonist  wnt_inhibitor
# 0         0.441580   0.443411                    0.443826       0.444846
# 1         0.448010   0.448741                    0.449386       0.450703
# 2         0.288531   0.289624                    0.290236       0.291373
# 3         0.360713   0.361717                    0.361822       0.363117
# 4         0.410086   0.411664                    0.411765       0.412669
#
# [5 rows x 207 columns]

# %%
feature_importance_df.to_csv('feature_importance.csv',index=False)
sample_submission.to_csv('submission.csv',index=False)

# %%
score_dict
# Out:
# {'5-alpha_reductase_inhibitor': 0.830160252528124,
#  '11-beta-hsd1_inhibitor': 0.6898790179488616,
#  'acat_inhibitor': 0.44420975199663726,
#  'acetylcholine_receptor_agonist': 0.6701940043131873,
#  'acetylcholine_receptor_antagonist': 0.6552813860092664,
#  'acetylcholinesterase_inhibitor': 0.5977091246690166,
#  'adenosine_receptor_agonist': 0.6331517333832148,
#  'adenosine_receptor_antagonist': 0.635331024959946,
#  'adenylyl_cyclase_activator': 0.9982669523569447,
#  'adrenergic_receptor_agonist': 0.7063918148525692,
#  'adrenergic_receptor_antagonist': 0.6605507944629203,
#  'akt_inhibitor': 0.8404848127561619,
#  'aldehyde_dehydrogenase_inhibitor': 0.9965016291726925,
#  'alk_inhibitor': 0.8841564305345224,
#  'ampk_activator': 0.5695389743158839,
#  'analgesic': 0.7063236982886593,
#  'androgen_receptor_agonist': 0.6216803066004657,
#  'androgen_receptor_antagonist': 0.6181586767857354,
#  'anesthetic_-_local': 0.6159446890536782,
#  'angiogenesis_inhibitor': 0.6073751647180867,
#  'angiotensin_receptor_antagonist': 0.6199302300997217,
#  'anti-inflammatory': 0.7261993441782986,
#  'antiarrhythmic': 0.6682557683691756,
#  'antibiotic': 0.7009743159781363,
#  'anticonvulsant': 0.6385072682967818,
#  'antifungal': 0.8827941941676658,
#  'antihistamine': 0.7415290731871271,
#  'antimalarial': 0.6102029285967763,
#  'antioxidant': 0.6215084822337866,
#  'antiprotozoal': 0.6084014401734563,
#  'antiviral': 0.6280544524509634,
#  'apoptosis_stimulant': 0.616329965607114,
#  'aromatase_inhibitor': 0.609163071628908,
#  'atm_kinase_inhibitor': 0.9186477934587813,
#  'atp_synthase_inhibitor': 0.9998319468952189,
#  'atpase_inhibitor': 0.7693567926612301,
#  'atr_kinase_inhibitor': 0.980723504495637,
#  'aurora_kinase_inhibitor': 0.9713772240492455,
#  'autotaxin_inhibitor': 0.7901265681003584,
#  'bacterial_30s_ribosomal_subunit_inhibitor': 0.6288863629985125,
#  'bacterial_50s_ribosomal_subunit_inhibitor': 0.6203213217325356,
#  'bacterial_antifolate': 0.7520116634423977,
#  'bacterial_cell_wall_synthesis_inhibitor': 0.6050806936683317,
#  'bacterial_dna_gyrase_inhibitor': 0.6283112916020412,
#  'bacterial_dna_inhibitor': 0.6175921933965293,
#  'bacterial_membrane_integrity_inhibitor': 0.9987578683340435,
#  'bcl_inhibitor': 0.8731460395267424,
#  'bcr-abl_inhibitor': 0.8208520755117943,
#  'benzodiazepine_receptor_agonist': 0.6635047066432271,
#  'beta_amyloid_inhibitor': 0.5496628485357994,
#  'bromodomain_inhibitor': 0.8905227381949159,
#  'btk_inhibitor': 0.8002087667538944,
#  'calcineurin_inhibitor': 0.6444752464157704,
#  'calcium_channel_blocker': 0.6626847768704596,
#  'cannabinoid_receptor_agonist': 0.657008946099052,
#  'cannabinoid_receptor_antagonist': 0.547874680982135,
#  'carbonic_anhydrase_inhibitor': 0.5709292436519284,
#  'casein_kinase_inhibitor': 0.7060623265203129,
#  'caspase_activator': 0.6549898675781177,
#  'catechol_o_methyltransferase_inhibitor': 0.694901338823068,
#  'cc_chemokine_receptor_antagonist': 0.6138854158397502,
#  'cck_receptor_antagonist': 0.647228292336714,
#  'cdk_inhibitor': 0.9731080444446673,
#  'chelating_agent': 0.6357147867564534,
#  'chk_inhibitor': 0.9874772313296903,
#  'chloride_channel_blocker': 0.6094595081848995,
#  'cholesterol_inhibitor': 0.5499821173104436,
#  'cholinergic_receptor_antagonist': 0.6501512033919441,
#  'coagulation_factor_inhibitor': 0.6648780521953405,
#  'corticosteroid_agonist': 0.9174318464313418,
#  'cyclooxygenase_inhibitor': 0.687651704324492,
#  'cytochrome_p450_inhibitor': 0.6537267219284301,
#  'dihydrofolate_reductase_inhibitor': 0.7750301399052345,
#  'dipeptidyl_peptidase_inhibitor': 0.6833570137458489,
#  'diuretic': 0.7775117607526881,
#  'dna_alkylating_agent': 0.7365546719403069,
#  'dna_inhibitor': 0.7113771225879827,
#  'dopamine_receptor_agonist': 0.6484179691110775,
#  'dopamine_receptor_antagonist': 0.7238842796873362,
#  'egfr_inhibitor': 0.9707686070850522,
#  'elastase_inhibitor': 0.7794613855286738,
#  'estrogen_receptor_agonist': 0.6784523315197151,
#  'estrogen_receptor_antagonist': 0.6584625445314034,
#  'faah_inhibitor': 0.7643018523191372,
#  'farnesyltransferase_inhibitor': 0.9895547337554398,
#  'fatty_acid_receptor_agonist': 0.8334154441128252,
#  'fgfr_inhibitor': 0.8652078774617066,
#  'flt3_inhibitor': 0.959878104219065,
#  'focal_adhesion_kinase_inhibitor': 0.9949874862255095,
#  'free_radical_scavenger': 0.6060215535757644,
#  'fungal_squalene_epoxidase_inhibitor': 0.7744470415374465,
#  'gaba_receptor_agonist': 0.5203497903740796,
#  'gaba_receptor_antagonist': 0.6312563667885246,
#  'gamma_secretase_inhibitor': 0.8616879427080202,
#  'glucocorticoid_receptor_agonist': 0.9770634863871075,
#  'glutamate_inhibitor': 0.7808366164317596,
#  'glutamate_receptor_agonist': 0.644171372299005,
#  'glutamate_receptor_antagonist': 0.6453702936496933,
#  'gonadotropin_receptor_agonist': 0.655445126164995,
#  'gsk_inhibitor': 0.8701348544806488,
#  'hcv_inhibitor': 0.6282461226705605,
#  'hdac_inhibitor': 0.9174058752558646,
#  'histamine_receptor_agonist': 0.6425291374875584,
#  'histamine_receptor_antagonist': 0.637834656112829,
#  'histone_lysine_demethylase_inhibitor': 0.9207580215776937,
#  'histone_lysine_methyltransferase_inhibitor': 0.8688950676982592,
#  'hiv_inhibitor': 0.6577756601053923,
#  'hmgcr_inhibitor': 0.9867029028544106,
#  'hsp_inhibitor': 0.936352843744008,
#  'igf-1_inhibitor': 0.9217708687364236,
#  'ikk_inhibitor': 0.8855953582240162,
#  'imidazoline_receptor_agonist': 0.6240992142666284,
#  'immunosuppressant': 0.7379880941184346,
#  'insulin_secretagogue': 0.5848364446686849,
#  'insulin_sensitizer': 0.8385486416929269,
#  'integrin_inhibitor': 0.6312733868576877,
#  'jak_inhibitor': 0.959293427858198,
#  'kit_inhibitor': 0.9697346675809783,
#  'laxative': 0.6036906362007168,
#  'leukotriene_inhibitor': 0.7908896169354839,
#  'leukotriene_receptor_antagonist': 0.6521169015308728,
#  'lipase_inhibitor': 0.5105645884099375,
#  'lipoxygenase_inhibitor': 0.6105506603825022,
#  'lxr_agonist': 0.8482582885304659,
#  'mdm_inhibitor': 0.9870916200647522,
#  'mek_inhibitor': 0.9210020451333314,
#  'membrane_integrity_inhibitor': 0.6237021562421732,
#  'mineralocorticoid_receptor_antagonist': 0.8218184875362562,
#  'monoacylglycerol_lipase_inhibitor': 0.7283736660784808,
#  'monoamine_oxidase_inhibitor': 0.6356419174353547,
#  'monopolar_spindle_1_kinase_inhibitor': 0.7728563157206627,
#  'mtor_inhibitor': 0.9251247190573318,
#  'mucolytic_agent': 0.7224808199388482,
#  'neuropeptide_receptor_antagonist': 0.7097149300539133,
#  'nfkb_inhibitor': 0.9504746450817698,
#  'nicotinic_receptor_agonist': 0.8052755376344086,
#  'nitric_oxide_donor': 0.689276105599462,
#  'nitric_oxide_production_inhibitor': 0.7461697896535304,
#  'nitric_oxide_synthase_inhibitor': 0.5719092367192249,
#  'norepinephrine_reuptake_inhibitor': 0.6168413851868298,
#  'nrf2_activator': 0.9148853215292954,
#  'opioid_receptor_agonist': 0.5886248708532417,
#  'opioid_receptor_antagonist': 0.6080618271636169,
#  'orexin_receptor_antagonist': 0.6460018709882023,
#  'p38_mapk_inhibitor': 0.9426316561457643,
#  'p-glycoprotein_inhibitor': 0.7204094857783383,
#  'parp_inhibitor': 0.8286263063923591,
#  'pdgfr_inhibitor': 0.973520695466522,
#  'pdk_inhibitor': 0.6773547374908948,
#  'phosphodiesterase_inhibitor': 0.6924964614295824,
#  'phospholipase_inhibitor': 0.7729101685653033,
#  'pi3k_inhibitor': 0.8582555323607174,
#  'pkc_inhibitor': 0.6360411950525788,
#  'potassium_channel_activator': 0.6790582707414223,
#  'potassium_channel_antagonist': 0.5900530856633427,
#  'ppar_receptor_agonist': 0.7536366421624835,
#  'ppar_receptor_antagonist': 0.6535913499271218,
#  'progesterone_receptor_agonist': 0.7709554722923142,
#  'progesterone_receptor_antagonist': 0.8056746231859696,
#  'prostaglandin_inhibitor': 0.6042501939234213,
#  'prostanoid_receptor_antagonist': 0.6221968876045993,
#  'proteasome_inhibitor': 0.9999955255637074,
#  'protein_kinase_inhibitor': 0.6808119617661085,
#  'protein_phosphatase_inhibitor': 0.761844758064516,
#  'protein_synthesis_inhibitor': 0.6788336739369258,
#  'protein_tyrosine_kinase_inhibitor': 0.6224593844350317,
#  'radiopaque_medium': 0.6451413358507812,
#  'raf_inhibitor': 0.9940761782491726,
#  'ras_gtpase_inhibitor': 0.6490998655575161,
#  'retinoid_receptor_agonist': 0.8832191843243044,
#  'retinoid_receptor_antagonist': 0.8684055779569892,
#  'rho_associated_kinase_inhibitor': 0.8729839654436988,
#  'ribonucleoside_reductase_inhibitor': 0.7760531697109061,
#  'rna_polymerase_inhibitor': 0.7590979023918618,
#  'serotonin_receptor_agonist': 0.6264024852239448,
#  'serotonin_receptor_antagonist': 0.7163242627124736,
#  'serotonin_reuptake_inhibitor': 0.6139337208857614,
#  'sigma_receptor_agonist': 0.618817230680087,
#  'sigma_receptor_antagonist': 0.6937657124699769,
#  'smoothened_receptor_antagonist': 0.6629324477699778,
#  'sodium_channel_inhibitor': 0.60703956657567,
#  'sphingosine_receptor_agonist': 0.7095851023582328,
#  'src_inhibitor': 0.8583214741424159,
#  'steroid': 0.7366046426971326,
#  'syk_inhibitor': 0.8823193727120913,
#  'tachykinin_antagonist': 0.6243450225926861,
#  'tgf-beta_receptor_inhibitor': 0.9993987554658594,
#  'thrombin_inhibitor': 0.8472810519680163,
#  'thymidylate_synthase_inhibitor': 0.7776570362682993,
#  'tlr_agonist': 0.5429252158313712,
#  'tlr_antagonist': 0.7131935985214432,
#  'tnf_inhibitor': 0.7223028289455238,
#  'topoisomerase_inhibitor': 0.9247570596715897,
#  'transient_receptor_potential_channel_antagonist': 0.5701331689733102,
#  'tropomyosin_receptor_kinase_inhibitor': 0.7245393705197132,
#  'trpv_agonist': 0.8030442641557022,
#  'trpv_antagonist': 0.5676443413559988,
#  'tubulin_inhibitor': 0.9632959605503728,
#  'tyrosine_kinase_inhibitor': 0.6616234674076925,
#  'ubiquitin_specific_protease_inhibitor': 0.7338989695340501,
#  'vegfr_inhibitor': 0.9001127011454217,
#  'vitamin_b': 0.6704705669309671,
#  'vitamin_d_receptor_agonist': 0.9157194855617569,
#  'wnt_inhibitor': 0.648637038905707}
